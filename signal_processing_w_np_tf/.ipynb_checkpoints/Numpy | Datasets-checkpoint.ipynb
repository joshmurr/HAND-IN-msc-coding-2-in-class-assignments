# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

fec_path = "./FEC_dataset/faceexp-comparison-data-test-public.csv"
sample_path = "./FEC_dataset/sample.csv"

data = pd.read_csv(sample_path, header=None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-18152ac86609> in <module>
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import matplotlib.pyplot as plt
#       4 plt.style.use('ggplot')
#       5
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data
# Out:
#                                                   0         1         2   \
# 0  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
# 1  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
# 2  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
# 3  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
# 4  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
# 5  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
# 6  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
# 7  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
# 8  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
# 9  http://farm4.staticflickr.com/3679/12137399835...  0.453125  0.655273
#
#          3         4                                                  5   \
# 0  0.079019  0.407357  http://farm4.staticflickr.com/3372/5791826985_...
# 1  0.079019  0.407357  http://farm6.staticflickr.com/5532/11255277973...
# 2  0.079019  0.407357  http://farm1.staticflickr.com/1/186137601_d1b8...
# 3  0.079019  0.407357  http://farm8.staticflickr.com/7345/11272369166...
# 4  0.079019  0.407357  http://farm4.staticflickr.com/3760/13641363095...
# 5  0.079019  0.407357  http://farm2.staticflickr.com/1183/1443593385_...
# 6  0.079019  0.407357  http://farm8.staticflickr.com/7027/6715442755_...
# 7  0.079019  0.407357  http://farm4.staticflickr.com/3671/9865480994_...
# 8  0.079019  0.407357  http://farm2.staticflickr.com/1369/5108165645_...
# 9  0.079019  0.407357  http://farm3.staticflickr.com/2400/1545630522_...
#
#          6         7         8         9   ...      18  19      20  21  \
# 0  0.523734  0.675633  0.155660  0.419811  ...  300701   3  321902   3
# 1  0.302734  0.568359  0.060150  0.535338  ...  300701   1  300901   3
# 2  0.311558  0.444724  0.178711  0.298828  ...  291701   3  300701   3
# 3  0.185547  0.260742  0.146245  0.263505  ...  291701   2  321902   3
# 4  0.408854  0.518229  0.277344  0.372070  ...  291701   2  321601   1
# 5  0.566406  0.688477  0.610677  0.799479  ...  300701   3  300901   3
# 6  0.341463  0.740418  0.000000  0.372857  ...  321601   2  322102   2
# 7  0.539062  0.654297  0.250366  0.450952  ...  321902   1   41207   1
# 8  0.450000  0.646250  0.278719  0.623352  ...  300901   1  321601   1
# 9  0.501953  0.574219  0.394531  0.507812  ...  291701   1  300701   1
#
#            22 23          24  25          26  27
# 0      322102  3  4294978797   3  4294989896   3
# 1      321501  3      321902   2      322102   3
# 2      321501  3      321601   3      321902   3
# 3      322102  2  4294989896   2       48316   3
# 4      322102  2  4294989896   2       48316   2
# 5      321601  2      322102   1  4294989896   1
# 6  4294978797  3  4294989896   2       48316   1
# 7  4294978797  1  4294989896   3       48316   1
# 8      321902  3      322102   1  4294978797   3
# 9      321501  2      321902   1      322102   1
#
# [10 rows x 28 columns]

# %%
# Add headers to 0 - 27 Columns

data.columns = ["a", "a_tl_x", "a_br_x", "a_tl_y", "a_br_y",
                "b", "b_tl_x", "b_br_x", "b_tl_y", "b_br_y",
                "c", "c_tl_x", "c_br_x", "c_tl_y", "c_br_y",
                "triplet", "annotator", "annotator", "annotator",
                "annotator", "annotator", "annotator", "annotator",
                "annotator", "annotator", "annotator", "annotator",
                "annotator"]

# %%
for url in data['c']:
    print(url)
# Out:
# http://farm3.staticflickr.com/2712/4239337027_0048b5131f_b.jpg
# http://farm4.staticflickr.com/3850/14926048846_77df12c39a_b.jpg
# http://farm6.staticflickr.com/5519/12358234664_c934ae3a42_b.jpg
# http://farm8.staticflickr.com/7325/8724273816_4760f61bfe_b.jpg
# http://farm4.staticflickr.com/3022/2819006049_fd84b93dc7_b.jpg
# http://farm5.staticflickr.com/4070/4406078243_38cb67c3cd_b.jpg
# http://farm4.staticflickr.com/3756/9769225545_7b4401beab_b.jpg
# http://farm6.staticflickr.com/5253/5510629681_76ffd3b7b0_b.jpg
# http://farm6.staticflickr.com/5593/14190816344_7266102414_b.jpg
# http://farm1.staticflickr.com/78/180074681_8ef34842b9_z.jpg

# %%
# Download images

import os
import urllib.request
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

try:
    os.mkdir('imgs')
    num_imgs = len(data['b'])
    for i in range(num_imgs):
        name = '00%03d.jpg' % i
        url = data['b'][i]
        print(name, end='\r')
        try:
            urllib.request.urlretrieve(url, os.path.join('imgs', name))
        except:
            print("skipping this one...")
except:
    print("Try removing the folder 'imgs'")
# Out:
# skipping this one...
# 00009.jpg

# %%
images = os.listdir('imgs')
# img = plt.imread(os.path.join('imgs', images[0]))

files = [os.path.join('imgs', file_i) for file_i in images if '.jpg' in file_i]
files = list(reversed(files))
print(files)
img = plt.imread(files[0])
plt.imshow(img)
# Out:
# ['imgs/00000.jpg', 'imgs/00001.jpg', 'imgs/00002.jpg', 'imgs/00006.jpg', 'imgs/00007.jpg', 'imgs/00005.jpg', 'imgs/00004.jpg', 'imgs/00009.jpg', 'imgs/00008.jpg']

# %%
img.shape
# Out:
# (424, 632, 3)

# %%
h = img.shape[0]
w = img.shape[1]
tl_x = int(round(data['b_tl_x'][0]*w))
br_x = int(round(data['b_br_x'][0]*w))
tl_y = int(round(data['b_tl_y'][0]*h))
br_y = int(round(data['b_br_y'][0]*h))

print(tl_x, br_x, tl_y, br_y)

head_width = br_x - tl_x
head_height = br_y - tl_y

print(head_width, head_height)
# Out:
# 331 427 66 178
# 96 112

# %%
plt.imshow(img, extent=[tl_x, br_x, tl_y, br_y])

# %%
drummer_data = np.array(img)

# %%
drummer_data.shape
# Out:
# (424, 632, 3)

# %%
drummer_face = drummer_data[tl_y:br_y, tl_x:br_x]

# %%
plt.imshow(drummer_face)
drummer_face.shape
# Out:
# (112, 96, 3)

# %%
from scipy import misc, ndimage
face = misc.face(gray=True).astype(float)

blurred_f = ndimage.gaussian_filter(drummer_face, 2)
filter_blurred_f = ndimage.gaussian_filter(blurred_f, 1)
alpha = 3
sharpened = blurred_f + alpha * (blurred_f - filter_blurred_f)

plt.imshow(blurred_f)

# %%
plt.imshow(sharpened)

# %%
# DE-NOISING
med_denoised = ndimage.median_filter(drummer_face, 3)
plt.imshow(med_denoised)
